# %%
import pandas as pd
import re
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
stopword_list = stopwords.words('english')
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.corpus import wordnet
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter
import datetime

# %%
df = pd.read_csv('csv/initial_reaction/iPhoneTweetsInitial.csv')

# %%
df.head()
# Out:
#   Unnamed: 0                   id      conversation_id  \
# 0          0  1438205036262268939  1438205036262268939
# 1          3  1438204990389211139  1438204644031873025
# 2          4  1438204983892013056  1438204983892013056
# 3          5  1438204964669513728  1438191408129662979
# 4         11  1438204931094106113  1438204931094106113
#
#                                   created_at        date      time timezone  \
# 0  2021-09-15 14:16:15 Eastern Daylight Time  2021-09-15  14:16:15     -400
# 1  2021-09-15 14:16:04 Eastern Daylight Time  2021-09-15  14:16:04     -400
# 2  2021-09-15 14:16:03 Eastern Daylight Time  2021-09-15  14:16:03     -400
# 3  2021-09-15 14:15:58 Eastern Daylight Time  2021-09-15  14:15:58     -400
# 4  2021-09-15 14:15:50 Eastern Daylight Time  2021-09-15  14:15:50     -400
#
#                user_id       username  \
# 0             48954798   richeenicole
# 1  1410841533834797059  obioracouture
# 2             15830701    iphone_news
# 3            190921309  thegorelander
# 4  1345357543950802948      phaseb_in
#
#                                         name  ...  geo source user_rt_id  \
# 0        Thug Passion (supa/soaker)🥷🏽🧜🏽‍♀️🇯🇲  ...  NaN    NaN        NaN
# 1                                       FELA  ...  NaN    NaN        NaN
# 2  All Apple, Always | News, Reviews, Guides  ...  NaN    NaN        NaN
# 3                         William Gorelander  ...  NaN    NaN        NaN
# 4                                    Phase-B  ...  NaN    NaN        NaN
#
#   user_rt retweet_id                                           reply_to  \
# 0     NaN        NaN                                                 []
# 1     NaN        NaN  [{'screen_name': 'abbietayo', 'name': 'Onion C...
# 2     NaN        NaN                                                 []
# 3     NaN        NaN  [{'screen_name': 'macworld', 'name': 'Macworld...
# 4     NaN        NaN                                                 []
#
#   retweet_date translate trans_src trans_dest
# 0          NaN       NaN       NaN        NaN
# 1          NaN       NaN       NaN        NaN
# 2          NaN       NaN       NaN        NaN
# 3          NaN       NaN       NaN        NaN
# 4          NaN       NaN       NaN        NaN
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13738 entries, 0 to 13737
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       13736 non-null  object
#  1   id               13737 non-null  object
#  2   conversation_id  13737 non-null  object
#  3   created_at       13737 non-null  object
#  4   date             13737 non-null  object
#  5   time             13737 non-null  object
#  6   timezone         13737 non-null  object
#  7   user_id          13737 non-null  object
#  8   username         13736 non-null  object
#  9   name             13736 non-null  object
#  10  place            14 non-null     object
#  11  tweet            13737 non-null  object
#  12  language         13737 non-null  object
#  13  mentions         13737 non-null  object
#  14  urls             13737 non-null  object
#  15  photos           13737 non-null  object
#  16  replies_count    13737 non-null  object
#  17  retweets_count   13737 non-null  object
#  18  likes_count      13737 non-null  object
#  19  hashtags         13737 non-null  object
#  20  cashtags         13737 non-null  object
#  21  link             13737 non-null  object
#  22  retweet          13737 non-null  object
#  23  quote_url        492 non-null    object
#  24  video            13737 non-null  object
#  25  thumbnail        2649 non-null   object
#  26  near             2 non-null      object
#  27  geo              2 non-null      object
#  28  source           2 non-null      object
#  29  user_rt_id       2 non-null      object
#  30  user_rt          2 non-null      object
#  31  retweet_id       2 non-null      object
#  32  reply_to         13737 non-null  object
#  33  retweet_date     2 non-null      object
#  34  translate        2 non-null      object
#  35  trans_src        2 non-null      object
#  36  trans_dest       2 non-null      object
# dtypes: object(37)
# memory usage: 3.9+ MB

# %%
tweets_df = df[['id', 'tweet']]

# %%
tweets_df.head()
# Out:
#                     id                                              tweet
# 0  1438205036262268939                         iPhone 13😑😑I expected more
# 1  1438204990389211139  @abbietayo You too pretty to be stressed. How ...
# 2  1438204983892013056  iPhone 13 versus iPhone 12 performance compari...
# 3  1438204964669513728               @macworld iPhone 13 NEEDED Touch ID!
# 4  1438204931094106113  Apple launched the new iPhone 13 mini on 14th ...

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13738 entries, 0 to 13737
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13737 non-null  object
#  1   tweet   13737 non-null  object
# dtypes: object(2)
# memory usage: 214.8+ KB

# %%
tweets_df['tweet'] = tweets_df['tweet'].astype(str)
# Out:
# <ipython-input-8-48edb74a62d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_df['tweet'] = tweets_df['tweet'].astype(str)

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13738 entries, 0 to 13737
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13737 non-null  object
#  1   tweet   13738 non-null  object
# dtypes: object(2)
# memory usage: 214.8+ KB

# %%
tweets_df.isna().sum()
# Out:
# id       1
# tweet    0
# dtype: int64

# %%
tweets_df = tweets_df.dropna()

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13737 entries, 0 to 13736
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      13737 non-null  object
#  1   tweet   13737 non-null  object
# dtypes: object(2)
# memory usage: 322.0+ KB

# %%
tweets_df.head()
# Out:
#                     id                                              tweet
# 0  1438205036262268939                         iPhone 13😑😑I expected more
# 1  1438204990389211139  @abbietayo You too pretty to be stressed. How ...
# 2  1438204983892013056  iPhone 13 versus iPhone 12 performance compari...
# 3  1438204964669513728               @macworld iPhone 13 NEEDED Touch ID!
# 4  1438204931094106113  Apple launched the new iPhone 13 mini on 14th ...

# %%
def clean_tweets(dataframe):
    # Add whitespace to the end of every tweet
    dataframe['clean_tweet'] = dataframe.tweet.map(lambda x: x + " ") 
    # Remove http links
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: re.sub(r'http.*', '', x))
    # Remove special characters and numbers
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: re.sub(r"[^a-zA-Z#]", ' ', x))
    # Lowercase all tweets
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: x.lower())
    #Tokenize tweets and remove stop words
    stopword_list = stopwords.words('english')
    for i in range(len(dataframe.clean_tweet)):
        tokens = word_tokenize(dataframe.clean_tweet[i])
        clean_tokens = [w for w in tokens if w not in stopword_list]
        dataframe.clean_tweet[i] = clean_tokens

# %%
clean_tweets(tweets_df)
tweets_df.head()
# Out:
#                     id                                              tweet  \
# 0  1438205036262268939                         iPhone 13😑😑I expected more
# 1  1438204990389211139  @abbietayo You too pretty to be stressed. How ...
# 2  1438204983892013056  iPhone 13 versus iPhone 12 performance compari...
# 3  1438204964669513728               @macworld iPhone 13 NEEDED Touch ID!
# 4  1438204931094106113  Apple launched the new iPhone 13 mini on 14th ...
#
#                                          clean_tweet
# 0                                 [iphone, expected]
# 1   [abbietayo, pretty, stressed, much, iphone, btw]
# 2  [iphone, versus, iphone, performance, comparis...
# 3              [macworld, iphone, needed, touch, id]
# 4  [apple, launched, new, iphone, mini, th, septe...

# %%
tweets_df.clean_tweet[4]
# Out:
# ['apple',
#  'launched',
#  'new',
#  'iphone',
#  'mini',
#  'th',
#  'september',
#  'california',
#  'event',
#  'apple',
#  'tim',
#  'cook',
#  '#',
#  'appleevent',
#  '#',
#  'apple',
#  '#',
#  'iphone',
#  'series',
#  '#',
#  'iphone',
#  '#',
#  'iphone',
#  'mini',
#  '#',
#  'phasebtweets']

# %%
def lemmatize_tweet(tweets):
    
    for i in range(len(tweets)):
        # Pos-tag each word in tweet
        for word in [tweets[i]]:
            pos_tag_list = nltk.pos_tag(word)
        # Convert pos-tag to be wordnet compliant
        wordnet_tags = []
        for j in pos_tag_list:
            # Adjective
            if j[1].startswith('J'):
                wordnet_tags.append(wordnet.ADJ)
            # Noun
            elif j[1].startswith('N'):
                wordnet_tags.append(wordnet.NOUN)
            # Adverb
            elif j[1].startswith('R'):
                wordnet_tags.append(wordnet.ADV)
            # Verb
            elif j[1].startswith('V'):
                wordnet_tags.append(wordnet.VERB)
            # Default to noun
            else:
                wordnet_tags.append(wordnet.NOUN)
        # Lemmatize each word in tweet
        lem_words = []
        for k in range(len(tweets[i])):
            lem_words.append(lemmatizer.lemmatize(tweets[i][k], pos=wordnet_tags[k]))
        lem_tweet = ' '.join(lem_words)
        tweets[i] = lem_tweet

# %%
lemmatize_tweet(tweets_df.clean_tweet)
tweets_df
# Out:
#                         id                                              tweet  \
# 0      1438205036262268939                         iPhone 13😑😑I expected more
# 1      1438204990389211139  @abbietayo You too pretty to be stressed. How ...
# 2      1438204983892013056  iPhone 13 versus iPhone 12 performance compari...
# 3      1438204964669513728               @macworld iPhone 13 NEEDED Touch ID!
# 4      1438204931094106113  Apple launched the new iPhone 13 mini on 14th ...
# ...                    ...                                                ...
# 13732  1438838899745320960  iPhone 13, iPhone 13 Mini, iPhone 13 Pro, and ...
# 13733  1438838899225370624  iPhone Secured! Decided against the pink 13. R...
# 13734  1438838897904062467  iPhone 13 Pro  UK Pre-orders now live  Play PS...
# 13735  1438838892757725190                              Iphone 13 pro cutieee
# 13736  1438838887577788421       Iphone 13 pro max in Sierra  Blue is ordered
#
#                                              clean_tweet
# 0                                          iphone expect
# 1                abbietayo pretty stress much iphone btw
# 2      iphone versus iphone performance comparison mi...
# 3                          macworld iphone need touch id
# 4      apple launch new iphone mini th september cali...
# ...                                                  ...
# 13732  iphone iphone mini iphone pro iphone pro max a...
# 13733  iphone secure decided pink realize spoiled pro...
# 13734  iphone pro uk pre order live play p game iphon...
# 13735                                 iphone pro cutieee
# 13736                   iphone pro max sierra blue order
#
# [13737 rows x 3 columns]

# %%
tweets_df.clean_tweet[4]
# Out:
# 'apple launch new iphone mini th september california event apple tim cook # appleevent # apple # iphone series # iphone # iphone mini # phasebtweets'

# %% [markdown]
# # EDA

# %%
# Join all the tweets into a single string
all_words_string = ' '.join([tweet for tweet in tweets_df.clean_tweet])

# Make a list of all the words in the dataframe
all_words_list = all_words_string.split()

# %%
# Plot word frequency distribution of first few words

plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
freq_dist = nltk.FreqDist(all_words_list)
freq_dist.plot(25,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Word Cloud with word frequencies

wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate_from_frequencies(freq_dist)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Remove 'apple, 'iphone', and '#'

def finish_cleaning(dataframe):
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: x.replace('apple',''))
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: x.replace('iphone',''))
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: x.replace('#',''))
    dataframe.clean_tweet = dataframe.clean_tweet.map(lambda x: x.replace('phone',''))

# %%
finish_cleaning(tweets_df)

# %%
# Join all the tweets into a single string
all_words_string = ' '.join([tweet for tweet in tweets_df.clean_tweet])

# Make a list of all the words in the dataframe
all_words_list = all_words_string.split()

# Plot word frequency distribution of first few words

plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
freq_dist = nltk.FreqDist(all_words_list)
freq_dist.plot(25,cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Word Cloud with word frequencies

wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate_from_frequencies(freq_dist)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Find the frequency of each word in the dataframe

word_freq = nltk.FreqDist(all_words_list)
freq_df = pd.DataFrame({'Word': list(word_freq.keys()), 'Count': list(word_freq.values())}).sort_values(by=['Count'], ascending=False)
freq_df.head(10)
# Out:
#         Word  Count
# 52       pro   5073
# 63       max   2233
# 16       new   2091
# 68       get   1967
# 73     order   1700
# 72       pre   1174
# 97       buy   1079
# 17      mini    914
# 21     event    866
# 133  upgrade    770

# %%
# Plot histogram of most frequent words

freq_df = freq_df.nlargest(columns="Count", n = 25) 
plt.figure(figsize=(16,5))
ax = sns.barplot(data=freq_df, x= "Word", y = "Count")
ax.set_ylabel('Count', fontsize=16)
ax.set_xlabel('Word', fontsize=16)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right", fontsize=12)
ax.set_title("Most Popular Words", fontsize=20)
plt.show()

# %%
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13737 entries, 0 to 13736
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           13737 non-null  object
#  1   tweet        13737 non-null  object
#  2   clean_tweet  13737 non-null  object
# dtypes: object(3)
# memory usage: 945.3+ KB

# %%
tweets_df.to_csv('iPhoneTweetsInitial_cleaned.csv')
