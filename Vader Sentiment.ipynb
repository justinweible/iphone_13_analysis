# %%
import pandas as pd
import nltk
#nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import re
from textblob import TextBlob
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

from nltk import word_tokenize
from nltk.corpus import stopwords
stopword_list = stopwords.words('english')
from nltk.stem.wordnet import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.corpus import wordnet
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from collections import Counter
import datetime

# %%
df = pd.read_csv('csv/cleaned_tweets.csv').drop(['Unnamed: 0'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65327 entries, 0 to 65326
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           65327 non-null  float64
#  1   tweet        65327 non-null  object
#  2   language     65327 non-null  object
#  3   date_time    65327 non-null  object
#  4   clean_tweet  64513 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.5+ MB

# %%
df.isna().sum()
# Out:
# id               0
# tweet            0
# language         0
# date_time        0
# clean_tweet    814
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65327 entries, 0 to 65326
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           65327 non-null  float64
#  1   tweet        65327 non-null  object
#  2   language     65327 non-null  object
#  3   date_time    65327 non-null  object
#  4   clean_tweet  64513 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 2.5+ MB

# %%
analyzer = SentimentIntensityAnalyzer()

scores = []
for sentence in df['tweet']:
  score = analyzer.polarity_scores(sentence)
  scores.append(score)
  
scores = pd.DataFrame(scores)

df['Compound'] = scores['compound']
df['Negative'] = scores['neg']
df['Neutral'] = scores['neu']
df['Positive'] = scores['pos']
df.head()
# Out:
#              id                                              tweet language  \
# 0  1.440000e+18  TG 13 iPhone 13 Giveaway!!!  https://t.co/Wffx...       en
# 1  1.440000e+18                     I kind of want the iPhone 13 🤔       en
# 2  1.440000e+18  TG 13 iPhone 13 Giveaway!!!  https://t.co/LN1B...       en
# 3  1.440000e+18  iphone 13 is another huge distraction from the...       en
# 4  1.440000e+18  @TrollTheMagic I know you are going to buy iPh...       en
#
#              date_time                                        clean_tweet  \
# 0  2021-09-26 10:23:04                                       tg  giveaway
# 1  2021-09-26 10:23:04                                         kind want
# 2  2021-09-26 10:22:51                                       tg  giveaway
# 3  2021-09-26 10:22:28   another huge distraction enemy well humble ge...
# 4  2021-09-26 10:22:09                 trollthemagic know go buy  pro max
#
#    Compound  Negative  Neutral  Positive
# 0    0.0000     0.000    1.000     0.000
# 1    0.0772     0.000    0.794     0.206
# 2    0.0000     0.000    1.000     0.000
# 3   -0.2263     0.251    0.535     0.214
# 4    0.0000     0.000    1.000     0.000

# %%
sentiment = []

for i in range(len(df)):
  if (df['Compound'][i] < 0):
    sentiment.append("Negative")
  elif (df['Compound'][i] > 0):
    sentiment.append("Positive")
  else:
    sentiment.append("Neutral")
    
sentiment = pd.DataFrame(sentiment)
df['Sentiment'] = sentiment
df.head()
# Out:
#              id                                              tweet language  \
# 0  1.440000e+18  TG 13 iPhone 13 Giveaway!!!  https://t.co/Wffx...       en
# 1  1.440000e+18                     I kind of want the iPhone 13 🤔       en
# 2  1.440000e+18  TG 13 iPhone 13 Giveaway!!!  https://t.co/LN1B...       en
# 3  1.440000e+18  iphone 13 is another huge distraction from the...       en
# 4  1.440000e+18  @TrollTheMagic I know you are going to buy iPh...       en
#
#              date_time                                        clean_tweet  \
# 0  2021-09-26 10:23:04                                       tg  giveaway
# 1  2021-09-26 10:23:04                                         kind want
# 2  2021-09-26 10:22:51                                       tg  giveaway
# 3  2021-09-26 10:22:28   another huge distraction enemy well humble ge...
# 4  2021-09-26 10:22:09                 trollthemagic know go buy  pro max
#
#    Compound  Negative  Neutral  Positive Sentiment
# 0    0.0000     0.000    1.000     0.000   Neutral
# 1    0.0772     0.000    0.794     0.206  Positive
# 2    0.0000     0.000    1.000     0.000   Neutral
# 3   -0.2263     0.251    0.535     0.214  Negative
# 4    0.0000     0.000    1.000     0.000   Neutral

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# id             0
# tweet          0
# language       0
# date_time      0
# clean_tweet    0
# Compound       0
# Negative       0
# Neutral        0
# Positive       0
# Sentiment      0
# dtype: int64

# %%
# WordCloud for all words
all_words = ' '.join([text for text in df['clean_tweet']])

wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate(all_words)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
negative_df = df[df['Sentiment'] == 'Negative']

# %%
negative_words = ' '.join([text for text in negative_df['clean_tweet']])

wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate(all_words)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
positive_df = df[df['Sentiment'] == 'Positive']

# %%
positive_df.head()
# Out:
#               id                                              tweet language  \
# 1   1.440000e+18                     I kind of want the iPhone 13 🤔       en
# 9   1.440000e+18  Apple will fix iPhone 13 'Unlock with Apple Wa...       en
# 11  1.440000e+18  iPhone 13 Unboxing 💙   Let’s see if this video...       en
# 14  1.440000e+18  @TmarTn  I hope with this giveaway and much mo...       en
# 19  1.440000e+18  Apple company shares crashes after iPhone 13 a...       en
#
#               date_time                                        clean_tweet  \
# 1   2021-09-26 10:23:04                                         kind want
# 9   2021-09-26 10:21:33   fix  unlock  watch soon day silence sunday  c...
# 11  2021-09-26 10:20:59        unboxing let see video well twitter like ig
# 14  2021-09-26 10:20:24  tmartn hope giveaway much upcoming channel rea...
# 19  2021-09-26 10:19:24                  company share crash  announcement
#
#     Compound  Negative  Neutral  Positive Sentiment
# 1     0.0772     0.000    0.794     0.206  Positive
# 9     0.2023     0.038    0.907     0.054  Positive
# 11    0.5983     0.000    0.766     0.234  Positive
# 14    0.8779     0.000    0.719     0.281  Positive
# 19    0.2960     0.000    0.784     0.216  Positive

# %%
positive_words = ' '.join([text for text in positive_df['clean_tweet']])

wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate(all_words)
plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df.to_csv('csv/tweet_sentiment.csv')

# %%
positive_df['clean_tweet'].value_counts()
# Out:
# win new                                                                                                                                                                                                                    437
# top rat  fast charger bundle star rating                                                                                                                                                                                   246
# attexplore                                                                                                                                                                                                                 126
#  cutie                                                                                                                                                                                                                     101
#  model color would prefer tweet photo mention latoken  giveaway tweet tag three friend                                                                                                                                      65
#                                                                                                                                                                                                                           ...
# want blue  pro                                                                                                                                                                                                               1
# thank forbes include  bookbook    surfacepad stun  case protect new investment pre order bookbook                                                                                                                            1
# new  pro week finally get chance test new camera system little bit  streetphotography  urbanphotography  streetstyle  nightphotography  streetclassics  urban addict  cinematic  photooftheday  streetscine  lphone pro      1
# thestudio mkbhd danggvinh brandonjhavard next see shot intro intro  pro review love u guy best video maker                                                                                                                   1
# new  pro land bionic chip mean smarter faster brighter battery last even longer everything need know innovative feature  pro find best deal                                                                                  1
# Name: clean_tweet, Length: 19288, dtype: int64

# %%
selected_words = ['battery', 'display', 'camera', 'pro', 'max', 'price', 'upgrade', 'color', 'screen']

# %%
positive_words_string = ' '.join([tweet for tweet in positive_df.clean_tweet])
positive_words_list = positive_words_string.split()

# %%
positive_words_list
# Out:
# ['kind',
#  'want',
#  'fix',
#  'unlock',
#  'watch',
#  'soon',
#  'day',
#  'silence',
#  'sunday',
#  'confirm',
#  'unlock',
#  'watch',
#  'feature',
#  'fix',
#  'software',
#  'patch',
#  'support',
#  'document',
#  'publish',
#  'sunday',
#  'confirm',
#  'issue',
#  'limit',
#  'unboxing',
#  'let',
#  'see',
#  'video',
#  'well',
#  'twitter',
#  'like',
#  'ig',
#  'tmartn',
#  'hope',
#  'giveaway',
#  'much',
#  'upcoming',
#  'channel',
#  'reach',
#  'many',
#  'people',
#  'become',
#  'part',
#  'community',
#  'well',
#  'good',
#  'luck',
#  'everyone',
#  'pro',
#  'max',
#  'company',
#  'share',
#  'crash',
#  'announcement',
#  'ok',
#  'mean',
#  'old',
#  'model',
#  'get',
#  'cheap',
#  'dog',
#  'awesome',
#  'normally',
#  'run',
#  'well',
#  'almost',
#  'device',
#  'recently',
#  'go',
#  'full',
#  'public',
#  'release',
#  'wait',
#  'new',
#  'pro',
#  'max',
#  'new',
#  'ipad',
#  'mini',
#  'sixth',
#  'generation',
#  'use',
#  'icloud',
#  'backgup',
#  'check',
#  'order',
#  'pro',
#  'virginmedia',
#  'make',
#  'sure',
#  'link',
#  'broadband',
#  'account',
#  'order',
#  'show',
#  'already',
#  'customer',
#  'virginmobile',
#  'dream',
#  'either',
#  'ipad',
#  'air',
#  'rise',
#  'gold',
#  'macbook',
#  'air',
#  'rise',
#  'gold',
#  'pink',
#  'life',
#  'favorite',
#  'color',
#  'pink',
#  'cute',
#  'lol',
#  'new',
#  'video',
#  'alert',
#  'android',
#  'fan',
#  'boy',
#  'unboxes',
#  'new',
#  'product',
#  'red',
#  'rt',
#  'appreciate',
#  'sandeepbrwayne',
#  'ztivom',
#  'overclockedthe',
#  'perspective',
#  'galaxy',
#  'acuire',
#  'potrait',
#  'video',
#  'mode',
#  'hz',
#  'refresh',
#  'rate',
#  'periscope',
#  'zoom',
#  'lense',
#  'punch',
#  'hole',
#  'design',
#  'display',
#  'fingerprint',
#  'pro',
#  'max',
#  'dude',
#  'well',
#  'go',
#  'play',
#  'ludo',
#  'shut',
#  'fuck',
#  'technicalguruji',
#  'youtubeindia',
#  'nice',
#  'wish',
#  'win',
#  'bureaurussell',
#  'matter',
#  'fact',
#  'use',
#  'pro',
#  'max',
#  'week',
#  'see',
#  'io',
#  'beta',
#  'watchos',
#  'beta',
#  'wish',
#  'would',
#  'keep',
#  'blue',
#  'color',
#  'like',
#  'series',
#  'join',
#  'mobiletrans',
#  'contest',
#  'win',
#  'one',
#  'look',
#  'like',
#  'either',
#  'get',
#  'pro',
#  'pro',
#  'max',
#  'base',
#  'deal',
#  'carrier',
#  'look',
#  'like',
#  'shot',
#  'either',
#  'way',
#  'crazy',
#  'shopping',
#  'everyone',
#  'either',
#  'unboxing',
#  'samsung',
#  'galaxy',
#  'z',
#  'flip',
#  'tiktok',
#  'love',
#  'see',
#  'get',
#  'pro',
#  'max',
#  'friday',
#  'holy',
#  'shit',
#  'battery',
#  'life',
#  'insane',
#  'currently',
#  'hour',
#  'screen',
#  'time',
#  'still',
#  'also',
#  'love',
#  'sierra',
#  'blue',
#  'hope',
#  'series',
#  'watch',
#  'color',
#  'geekyranjit',
#  'want',
#  'best',
#  'phone',
#  'matket',
#  'video',
#  'record',
#  'android',
#  'bar',
#  'series',
#  'well',
#  'android',
#  'phone',
#  'opinion',
#  'talk',
#  'upgrades',
#  'life',
#  'xr',
#  'pro',
#  'dog',
#  'cool',
#  'puppy',
#  'drop',
#  'lbs',
#  'month',
#  'silver',
#  'gold',
#  'product',
#  'expert',
#  'life',
#  'good',
#  'willing',
#  'make',
#  'good',
#  'need',
#  'passion',
#  'energy',
#  'amp',
#  'goal',
#  'foodhealth',
#  'congratulation',
#  'cost',
#  'definitely',
#  'rs',
#  'first',
#  'digit',
#  'guess',
#  'spent',
#  'accessory',
#  'best',
#  'tech',
#  'abelhato',
#  'mini',
#  'mah',
#  'battery',
#  'mini',
#  'mah',
#  'battery',
#  'accord',
#  'calculation',
#  'mean',
#  'mini',
#  'battery',
#  'capacity',
#  'mini',
#  'bad',
#  'best',
#  'trick',
#  'tip',
#  'include',
#  'macro',
#  'photography',
#  'cinematic',
#  'video',
#  'get',
#  'next',
#  'week',
#  'excite',
#  'buy',
#  'pink',
#  'im',
#  'excite',
#  'pink',
#  'cutie',
#  'andyr',
#  'pro',
#  'think',
#  'much',
#  'good',
#  'x',
#  'ahaha',
#  'like',
#  'youtube',
#  'best',
#  'pro',
#  'case',
#  'accessory',
#  'iwitness',
#  'smile',
#  'osmaniespinosa',
#  'joshuaswingle',
#  'jon',
#  'prosser',
#  'rendersbyian',
#  'thats',
#  'true',
#  'redesign',
#  'right',
#  'wait',
#  'instead',
#  'buy',
#  'like',
#  'wait',
#  'x',
#  'techlimitedone',
#  'pro',
#  'lookxxx',
#  'sexy',
#  'feature',
#  'update',
#  'per',
#  'demand',
#  'think',
#  'wait',
#  'thanks',
#  'pro',
#  'giveaway',
#  'awesome',
#  'actually',
#  'pretty',
#  'want',
#  'gold',
#  'max',
#  'smfh',
#  'joshuaswingle',
#  'jon',
#  'prosser',
#  'rendersbyian',
#  'strange',
#  'fact',
#  'tell',
#  'u',
#  'much',
#  'far',
#  'ahead',
#  'almost',
#  'like',
#  'get',
#  'get',
#  'u',
#  'op',
#  'annoys',
#  'pink',
#  'look',
#  'like',
#  'white',
#  'amp',
#  'get',
#  'stain',
#  'like',
#  'happens',
#  'silicone',
#  'phone',
#  'cover',
#  'clown',
#  'funny',
#  'joker',
#  'pro',
#  'max',
#  'case',
#  'camoucase',
#  'ar',
#  'thank',
#  'much',
#  'sir',
#  'look',
#  'sensational',
#  'pro',
#  'max',
#  'cubswin',
#  'late',
#  'night',
#  'cause',
#  'issue',
#  'e',
#  'set',
#  'carplay',
#  'still',
#  'crash',
#  'try',
#  'play',
#  'song',
#  'nicolasgargala',
#  'overclockedthe',
#  'true',
#  's',
#  'beast',
#  'samsung',
#  'base',
#  'preference',
#  'need',
#  'fight',
#  'ultra',
#  'one',
#  'pro',
#  'max',
#  'rival',
#  'ultra',
#  'end',
#  'come',
#  'wat',
#  'u',
#  'love',
#  'android',
#  'samsung',
#  'join',
#  'mobiletrans',
#  'contest',
#  'win',
#  'one',
#  'ready',
#  'avakian',
#  'hi',
#  'help',
#  'aware',
#  'issue',
#  'unlock',
#  'watch',
#  'may',
#  'work',
#  'device',
#  'issue',
#  'fix',
#  'upcoming',
#  'software',
#  'update',
#  'resource',
#  'two',
#  'day',
#  'pro',
#  'admit',
#  'speaker',
#  'literally',
#  'scare',
#  'shit',
#  'morning',
#  'alarm',
#  'go',
#  'lmao',
#  'accord',
#  'mrwhosetheboss',
#  'pro',
#  'max',
#  'win',
#  'battery',
#  'life',
#  'test',
#  'lineup',
#  'achieve',
#  'impressive',
#  'hour',
#  'minute',
#  'battery',
#  'life',
#  'continuous',
#  'usage',
#  'long',
#  'battery',
#  'life',
#  'ever',
#  'test',
#  'best',
#  'case',
#  'top',
#  'cover',
#  'protect',
#  'new',
#  'smartphone',
#  'deliver',
#  'promised',
#  'congratulation',
#  'ms',
#  'mafuza',
#  'akhter',
#  'nd',
#  'lucky',
#  'draw',
#  'winner',
#  'pro',
#  'ace',
#  'money',
#  'transfer',
#  'keep',
#  'use',
#  'ace',
#  'money',
#  'transfer',
#  'trust',
#  'remittance',
#  'partner',
#  'stand',
#  'chance',
#  'become',
#  'lucky',
#  'winner',
#  'amp',
#  'c',
#  'apply',
#  'mark',
#  'tech',
#  'lmao',
#  'show',
#  'sample',
#  'lenses',
#  'x',
#  'ultra',
#  'weak',
#  'pro',
#  'make',
#  'look',
#  'like',
#  'waay',
#  'ahead',
#  'minor',
#  'upgrade',
#  'pro',
#  'max',
#  'v',
#  'galaxy',
#  'ultra',
#  'speed',
#  'test',
#  'indian',
#  'unboxing',
#  'amp',
#  'first',
#  'impression',
#  'giveaway',
#  'juta',
#  'rupiah',
#  'pro',
#  'one',
#  'winner',
#  'rt',
#  'follow',
#  'join',
#  'pinned',
#  'end',
#  'day',
#  'goodluck',
#  'buy',
#  'cause',
#  'thirteen',
#  'number',
#  'mcwm',
#  'love',
#  'massive',
#  'upgrade',
#  'come',
#  'pro',
#  'max',
#  'feel',
#  'great',
#  'hand',
#  'really',
#  'happy',
#  'far',
#  'anthony',
#  'joshua',
#  'fantastic',
#  'product',
#  'real',
#  'deal',
#  'however',
#  'ram',
#  'throat',
#  'day',
#  'leave',
#  'bitter',
#  'taste',
#  'encode',
#  'serial',
#  'number',
#  'battery',
#  'eventually',
#  'manufacturer',
#  'follow',
#  'backbone',
#  'create',
#  'adapter',
#  'pro',
#  'use',
#  'old',
#  'controller',
#  'clip',
#  'amazonin',
#  'would',
#  'like',
#  'buy',
#  'pro',
#  'festive',
#  'season',
#  'ipad',
#  'study',
#  'amazonin',
#  'amazongreatindianfestival',
#  'jimmygunawanapp',
#  'schappi',
#  'thx',
#  'phone',
#  'camera',
#  'well',
#  'zoom',
#  'far',
#  'see',
#  'ask',
#  'photogrammetry',
#  'similar',
#  'apps',
#  'edge',
#  'still',
#  'game',
#  'pro',
#  'max',
#  'tissueman',
#  'hatty',
#  'gold',
#  'tempesttdev',
#  'normal',
#  'test',
#  'competitor',
#  'like',
#  'release',
#  'yet',
#  'pretty',
#  'much',
#  'model',
#  'except',
#  'pro',
#  'max',
#  'still',
#  'beat',
#  'old',
#  'ultra',
#  'battery',
#  'life',
#  'though',
#  'help',
#  'win',
#  'free',
#  'support',
#  'would',
#  'like',
#  'buy',
#  'want',
#  'unlock',
#  'connect',
#  'later',
#  'ssddsam',
#  'snapchat',
#  'accord',
#  'taz',
#  'duchofnarsussex',
#  'sparklemeghan',
#  'thetoadours',
#  'coopevivienne',
#  'mailonline',
#  'nypost',
#  'people',
#  'gbnews',
#  'cbsnews',
#  'like',
#  'see',
#  'slight',
#  'blue',
#  'shade',
#  'store',
#  'click',
#  'snap',
#  'take',
#  'launch',
#  'come',
#  'really',
#  'cool',
#  'look',
#  'time',
#  'suare',
#  'etc',
#  'people',
#  'go',
#  'area',
#  'guy',
#  'play',
#  'basketball',
#  'harlem',
#  'chat',
#  'want',
#  'aapltree',
#  'mattbirchler',
#  'dominocollege',
#  'well',
#  'look',
#  'much',
#  'improve',
#  'battery',
#  'capacity',
#  'mini',
#  'mah',
#  'mah',
#  'pro',
#  'mah',
#  'pro',
#  'max',
#  'mah',
#  'mini',
#  'mah',
#  'mah',
#  'pro',
#  'mah',
#  'pro',
#  'max',
#  'mah',
#  'upgrade',
#  'happy',
#  'haha',
#  'beautiful',
#  'spectre',
#  'massively',
#  'benefit',
#  'every',
#  'camera',
#  'improvement',
#  'even',
#  'macro',
#  'long',
#  'exposure',
#  'pro',
#  'trade',
#  'samsung',
#  'switch',
#  'every',
#  'month',
#  'mainly',
#  'medium',
#  'content',
#  'creation',
#  'apps',
#  'video',
#  'stuff',
#  'samsung',
#  'allows',
#  'edit',
#  'share',
#  'ease',
#  'discreet',
#  'arguably',
#  'cheap',
#  'love',
#  'shoot',
#  'camera',
#  'judge',
#  'review',
#  'picture',
#  'uality',
#  'mirrorless',
#  'dslr',
#  'advantage',
#  'fade',
#  'away',
#  'become',
#  'secondary',
#  'make',
#  'good',
#  'camera',
#  'series',
#  'launch',
#  'everything',
#  'need',
#  'know',
#  'pro',
#  'v',
#  'pro',
#  'zoom',
#  'pretty',
#  'impressed',
#  'pro',
#  'sadly',
#  'x',
#  'still',
#  'compare',
#  'x',
#  'ultra',
#  'zollotech',
#  'consider',
#  'go',
#  'due',
#  'advance',
#  'battery',
#  'decay',
#  'worth',
#  'cinematic',
#  'mode',
#  'test',
#  'pro',
#  'max',
#  'go',
#  'well',
#  'never',
#  'work',
#  'child',
#  'animal',
#  'best',
#  'part',
#  'own',
#  'india',
#  'right',
#  'phone',
#  'case',
#  'available',
#  'moment',
#  'daisyskidd',
#  'wait',
#  'actually',
#  'good',
#  'literally',
#  'hear',
#  'anything',
#  'acknowledges',
#  'refresh',
#  'rate',
#  'issue',
#  'series',
#  'promise',
#  'fix',
#  'soon',
#  'penguinguy',
#  'thanks',
#  'reach',
#  'u',
#  'know',
#  'important',
#  'use',
#  'new',
#  'pro',
#  'watch',
#  'guidance',
#  'io',
#  'pro',
#  'already',
#  'time',
#  'go',
#  'final',
#  'io',
#  'review',
#  'follow',
#  'io',
#  'follow',
#  'hope',
#  'great',
#  'day',
#  'ios',
#  'final',
#  'review',
#  'io',
#  'come',
#  'soon',
#  'supersaf',
#  'answer',
#  'samsung',
#  'normally',
#  'work',
#  'lol',
#  'small',
#  'notch',
#  'opt',
#  'anything',
#  'useful',
#  'extra',
#  'space',
#  'lol',
#  'even',
#  'battery',
#  'percentage',
#  'point',
#  'small',
#  'notch',
#  'get',
#  'wrong',
#  'pro',
#  'amaze',
#  'cmon',
#  'ee',
#  'hey',
#  'look',
#  'cancel',
#  'vodafoneuk',
#  'want',
#  'get',
#  'new',
#  'order',
#  'today',
#  'get',
#  'pro',
#  'max',
#  'gb',
#  'graphite',
#  'experience',
#  'delay',
#  'want',
#  'get',
#  'idea',
#  'order',
#  'thanks',
#  'ragiing',
#  'bull',
#  'maybe',
#  'come',
#  'collect',
#  'delivery',
#  'pro',
#  'max',
#  'fresh',
#  'frm',
#  'usa',
#  'think',
#  'upgrade',
#  'get',
#  'good',
#  'video',
#  'show',
#  'understand',
#  'people',
#  'tik',
#  'tok',
#  'man',
#  'girl',
#  'show',
#  'excite',
#  'everyone',
#  'comment',
#  'mad',
#  'call',
#  'spoilt',
#  'like',
#  'bro',
#  'let',
#  'moment',
#  'happy',
#  'third',
#  'party',
#  'apps',
#  'able',
#  'take',
#  'benefit',
#  'pro',
#  'hz',
#  'promotion',
#  'display',
#  'default',
#  'pocketnow',
#  'publish',
#  'canada',
#  'news',
#  'medium',
#  'check',
#  'esr',
#  'clear',
#  ...]

# %%
positive_dict_counts = Counter(positive_words_list)

# %%
positive_output_dict_counts = dict((k, positive_dict_counts[k]) for k in selected_words)

positive_output_dict_counts
# Out:
# {'battery': 1413,
#  'display': 593,
#  'camera': 2304,
#  'pro': 13656,
#  'max': 6232,
#  'price': 461,
#  'upgrade': 1047,
#  'color': 578,
#  'screen': 1016}

# %%
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
freq_dist = nltk.FreqDist(positive_output_dict_counts)
freq_dist.plot(cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
negative_words_string = ' '.join([tweet for tweet in negative_df.clean_tweet])
negative_words_list = negative_words_string.split()

# %%
negative_words_list
# Out:
# ['another',
#  'huge',
#  'distraction',
#  'enemy',
#  'well',
#  'humble',
#  'get',
#  'flip',
#  'phone',
#  'lol',
#  'promise',
#  'fix',
#  'broken',
#  'unlock',
#  'watch',
#  'feature',
#  'absolutely',
#  'reason',
#  'people',
#  'buy',
#  'cause',
#  'really',
#  'nothing',
#  'promise',
#  'fix',
#  'broken',
#  'unlock',
#  'watch',
#  'feature',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'face',
#  'id',
#  'stop',
#  'work',
#  'replace',
#  'screen',
#  'third',
#  'party',
#  'repair',
#  'video',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'could',
#  'absolutely',
#  'care',
#  'less',
#  'cinematic',
#  'mode',
#  'whatever',
#  'make',
#  'round',
#  'shitty',
#  'focus',
#  'pull',
#  'mechanic',
#  'cap',
#  'p',
#  'rendersbyian',
#  'mac',
#  'joseadorno',
#  'real',
#  'design',
#  'buy',
#  'second',
#  'come',
#  'go',
#  'tbh',
#  'name',
#  'bubblepins',
#  'get',
#  'black',
#  'pro',
#  'fit',
#  'color',
#  'soul',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'today',
#  'say',
#  'issue',
#  'prevent',
#  'user',
#  'use',
#  'unlock',
#  'watch',
#  'feature',
#  'fix',
#  'run',
#  'hz',
#  'situation',
#  'prove',
#  'one',
#  'tech',
#  'twitter',
#  'know',
#  'talk',
#  'feel',
#  'like',
#  'clown',
#  'pre',
#  'order',
#  'pro',
#  'max',
#  'last',
#  'week',
#  'amp',
#  'still',
#  'mine',
#  'outrageous',
#  'even',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'receive',
#  'minor',
#  'external',
#  'change',
#  'early',
#  'insider',
#  'report',
#  'abandon',
#  'cutout',
#  'screen',
#  'instead',
#  'display',
#  'round',
#  'hole',
#  'front',
#  'camera',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'crazy',
#  'shopping',
#  'face',
#  'id',
#  'stop',
#  'work',
#  'replace',
#  'screen',
#  'third',
#  'party',
#  'repair',
#  'video',
#  'yes',
#  'horrible',
#  'lens',
#  'flare',
#  'still',
#  'notice',
#  'artistic',
#  'shape',
#  'compare',
#  'last',
#  'year',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'face',
#  'id',
#  'stop',
#  'work',
#  'replace',
#  'screen',
#  'third',
#  'party',
#  'repair',
#  'video',
#  'snazzy',
#  'leave',
#  'midranger',
#  'think',
#  'right',
#  'leave',
#  'image',
#  'low',
#  'resolution',
#  'thats',
#  'blury',
#  'ztivom',
#  'elitetechrev',
#  'overclockedthe',
#  'rival',
#  'ultra',
#  'tech',
#  'guy',
#  'compare',
#  'wrong',
#  'phone',
#  'chill',
#  'wait',
#  'ultra',
#  'guy',
#  'know',
#  's',
#  'start',
#  'tech',
#  'season',
#  'android',
#  'follow',
#  'month',
#  'fix',
#  'issue',
#  'prevent',
#  'user',
#  'unlock',
#  'watch',
#  'upcoming',
#  'software',
#  'update',
#  'fail',
#  'buyer',
#  'say',
#  'new',
#  'mobile',
#  'play',
#  'music',
#  'jcieplinski',
#  'safari',
#  'load',
#  'something',
#  'wrong',
#  'even',
#  'transfer',
#  'pro',
#  'max',
#  'want',
#  'damn',
#  'fuggittt',
#  'crazy',
#  'shopping',
#  'attexplore',
#  'ah',
#  'capobianco',
#  'lori',
#  'need',
#  'new',
#  'phone',
#  'bad',
#  'problem',
#  'get',
#  'every',
#  'new',
#  'come',
#  'bout',
#  'go',
#  'get',
#  'noww',
#  'englishdanyt',
#  'dan',
#  'know',
#  'turn',
#  'notification',
#  'use',
#  'keyboard',
#  'watch',
#  'move',
#  'somehow',
#  'annoy',
#  'notification',
#  'come',
#  'momsfocus',
#  'vzwsupport',
#  'enough',
#  'icloud',
#  'space',
#  'pro',
#  'gb',
#  'connect',
#  'wi',
#  'fi',
#  'night',
#  'back',
#  'since',
#  'set',
#  'morning',
#  'tooyib',
#  'amp',
#  'wahala',
#  'smh',
#  'daughter',
#  'ask',
#  'buy',
#  'ignored',
#  'kukuma',
#  'take',
#  'saving',
#  'buy',
#  'one',
#  'boom',
#  'na',
#  'announce',
#  'laugh',
#  'ehn',
#  'tell',
#  'wait',
#  'till',
#  'september',
#  'say',
#  'teamsamsung',
#  'life',
#  'czareemarcel',
#  'tim',
#  'cook',
#  'im',
#  'poor',
#  'girl',
#  'stand',
#  'front',
#  'ceo',
#  'ask',
#  'pro',
#  'max',
#  'tb',
#  'face',
#  'id',
#  'stop',
#  'work',
#  'replace',
#  'screen',
#  'third',
#  'party',
#  'repair',
#  'video',
#  'pro',
#  'camera',
#  'go',
#  'hard',
#  'zacksjerryrig',
#  'type',
#  'c',
#  'still',
#  'ugly',
#  'notch',
#  'top',
#  'touch',
#  'id',
#  'phone',
#  'hand',
#  'pick',
#  'improvement',
#  'lineup',
#  'dumb',
#  'bobbykatsigazi',
#  'mr',
#  'honey',
#  'tweet',
#  'use',
#  'still',
#  'think',
#  'buy',
#  'magic',
#  'wen',
#  'arsenal',
#  'loss',
#  'own',
#  'spur',
#  'wait',
#  'case',
#  'screen',
#  'protector',
#  'pm',
#  'torture',
#  'know',
#  'scratch',
#  'screen',
#  'side',
#  'ellielovegrovee',
#  'xr',
#  'rn',
#  'buy',
#  'pro',
#  'max',
#  'break',
#  'battery',
#  'life',
#  'crazy',
#  'new',
#  'camera',
#  'trick',
#  'include',
#  'cinematic',
#  'video',
#  'macro',
#  'photography',
#  'enough',
#  'icloud',
#  'space',
#  'pro',
#  'gb',
#  'connect',
#  'wi',
#  'fi',
#  'night',
#  'back',
#  'since',
#  'set',
#  'morning',
#  'though',
#  'alteredtech',
#  'look',
#  'one',
#  'previous',
#  'post',
#  'try',
#  'lessen',
#  'severity',
#  'flare',
#  'software',
#  'release',
#  'youtube',
#  'video',
#  'soon',
#  'compare',
#  'promax',
#  'promax',
#  'agree',
#  'macro',
#  'lens',
#  'annoy',
#  'sometimes',
#  'crazy',
#  'shopping',
#  'tryna',
#  'see',
#  'get',
#  'want',
#  'get',
#  'pro',
#  'max',
#  'hate',
#  'need',
#  'maxx',
#  'karzovicfn',
#  'wtf',
#  'way',
#  'expesnsive',
#  'u',
#  'get',
#  'pro',
#  'max',
#  'tb',
#  'k',
#  'crazy',
#  'shopping',
#  'io',
#  'key',
#  'feature',
#  'tease',
#  'via',
#  'tip',
#  'app',
#  'notification',
#  'ahead',
#  'launch',
#  'event',
#  'day',
#  'delay',
#  'pro',
#  'max',
#  'need',
#  'facebook',
#  'business',
#  'suite',
#  'update',
#  'rollout',
#  'cancel',
#  'amp',
#  'do',
#  'button',
#  'top',
#  'battery',
#  'wi',
#  'fi',
#  'etc',
#  'pro',
#  'stiff',
#  'annie',
#  'hi',
#  'steph',
#  'sosorry',
#  'customer',
#  'pre',
#  'order',
#  'receive',
#  'phone',
#  'later',
#  'expect',
#  'due',
#  'delay',
#  'receive',
#  'supply',
#  'work',
#  'closely',
#  'get',
#  'order',
#  'soon',
#  'possible',
#  'dpd',
#  'notify',
#  'soon',
#  'way',
#  'kie',
#  'trading',
#  'pro',
#  'max',
#  'black',
#  'gb',
#  'month',
#  'old',
#  'scratch',
#  'drop',
#  'pro',
#  'gb',
#  'top',
#  'need',
#  'dm',
#  'cromaretail',
#  'order',
#  'id',
#  'book',
#  'pro',
#  'max',
#  'call',
#  'store',
#  'schedule',
#  'pick',
#  'deny',
#  'inventory',
#  'inform',
#  'one',
#  'piece',
#  'available',
#  'website',
#  'told',
#  'could',
#  'customer',
#  'pre',
#  'book',
#  'badeen',
#  'stop',
#  'work',
#  'beta',
#  'kingpmoney',
#  'come',
#  'day',
#  'ago',
#  'mad',
#  'pastel',
#  'pink',
#  'color',
#  'cry',
#  'saw',
#  'pro',
#  'store',
#  'pretty',
#  'omg',
#  'camera',
#  'clear',
#  'there',
#  'reason',
#  'phone',
#  'expensive',
#  'wtf',
#  'maxwell',
#  'asante',
#  'pablo',
#  'lastking',
#  'gyaigyimii',
#  'want',
#  'buy',
#  'new',
#  'buh',
#  'get',
#  'upgrade',
#  'yet',
#  'color',
#  'go',
#  'torn',
#  'new',
#  'blue',
#  'color',
#  'normal',
#  'graphite',
#  'yo',
#  'really',
#  'difference',
#  'new',
#  'bitch',
#  'put',
#  'jbl',
#  'speaker',
#  'shit',
#  'loud',
#  'everyone',
#  'gon',
#  'na',
#  'gettin',
#  'upgrade',
#  'goin',
#  'back',
#  'android',
#  'sorry',
#  'kinda',
#  'need',
#  'wire',
#  'charger',
#  'semi',
#  'conversation',
#  'pro',
#  'fake',
#  'hz',
#  'comparison',
#  'x',
#  'shots',
#  'pro',
#  'v',
#  'galaxy',
#  'ultra',
#  'interesting',
#  'might',
#  'talk',
#  'later',
#  'first',
#  'image',
#  'shatter',
#  'pro',
#  'appear',
#  'online',
#  'attexplore',
#  'shergib',
#  'attexplore',
#  'cancel',
#  'amp',
#  'order',
#  'eshumarneedi',
#  'soycabuernigu',
#  'snazzy',
#  'need',
#  'snark',
#  'everyone',
#  'know',
#  'every',
#  'specific',
#  'term',
#  'field',
#  'lingo',
#  'mention',
#  'macro',
#  'multiple',
#  'meaning',
#  'across',
#  'different',
#  'field',
#  'computer',
#  'vs',
#  'photography',
#  'answer',
#  'camera',
#  'focus',
#  'object',
#  'close',
#  'lens',
#  'macro',
#  'mode',
#  'jordanmorgan',
#  'ui',
#  'refresh',
#  'trouble',
#  'mine',
#  'mini',
#  'simu',
#  'another',
#  'shot',
#  'astro',
#  'pro',
#  'use',
#  'nightcap',
#  'app',
#  'first',
#  'attempt',
#  'star',
#  'overexpose',
#  'wb',
#  'great',
#  'still',
#  'impressed',
#  'nikon',
#  'take',
#  'age',
#  'post',
#  'face',
#  'id',
#  'watch',
#  'bypass',
#  'work',
#  'yet',
#  'smh',
#  'yessssirrrrrr',
#  'hype',
#  'rn',
#  'lil',
#  'weak',
#  'as',
#  'imma',
#  'upgrade',
#  'pro',
#  'max',
#  'keep',
#  'bitch',
#  'till',
#  'break',
#  'like',
#  'phone',
#  'battery',
#  'life',
#  'pro',
#  'max',
#  'insane',
#  'everypro',
#  'release',
#  'rebel',
#  'series',
#  'gen',
#  'mini',
#  'price',
#  'sell',
#  'exaggerated',
#  'price',
#  'ira',
#  'price',
#  'pro',
#  'max',
#  'gb',
#  'use',
#  'gb',
#  'old',
#  'phone',
#  'leave',
#  'go',
#  'gb',
#  'pro',
#  'show',
#  'gb',
#  'photo',
#  'make',
#  'sense',
#  'wtf',
#  'charge',
#  'phone',
#  'hour',
#  'shit',
#  'battery',
#  'playinnnn',
#  'crazy',
#  'shopping',
#  'mine',
#  'throughout',
#  'year',
#  'c',
#  'break',
#  'get',
#  'samsung',
#  'galexy',
#  'mainly',
#  'use',
#  'bc',
#  'gb',
#  'data',
#  'share',
#  'one',
#  'barely',
#  'unlimited',
#  'also',
#  'storage',
#  'plus',
#  'x',
#  'pro',
#  'max',
#  'nws',
#  'new',
#  'pro',
#  'act',
#  'wire',
#  'lags',
#  'get',
#  'stuck',
#  'phone',
#  'act',
#  'stupid',
#  'idc',
#  'get',
#  'little',
#  'regret',
#  'buying',
#  'saw',
#  'uality',
#  'photo',
#  'yesterday',
#  'dont',
#  'need',
#  'fuck',
#  'everyone',
#  'fuck',
#  'standard',
#  'fuck',
#  'everything',
#  'camera',
#  'uality',
#  'pristine',
#  'stop',
#  'taking',
#  'picture',
#  'cat',
#  'snazzy',
#  'pro',
#  'open',
#  'instagram',
#  'try',
#  'select',
#  'icon',
#  'upper',
#  'right',
#  'corner',
#  'bad',
#  'watch',
#  'ifixit',
#  'go',
#  'live',
#  'teardown',
#  'review',
#  'geek',
#  'hate',
#  'get',
#  'phone',
#  'right',
#  'release',
#  'upgrade',
#  'eligible',
#  'along',
#  'promax',
#  'shit',
#  'bed',
#  'sooo',
#  'go',
#  'kinda',
#  'sad',
#  'get',
#  'able',
#  'use',
#  'bear',
#  'case',
#  'share',
#  'yeobie',
#  'skyhelpteam',
#  'strange',
#  'pro',
#  'max',
#  'pro',
#  'max',
#  'price',
#  'website',
#  'expect',
#  'pro',
#  'max',
#  'drop',
#  'price',
#  'macrumors',
#  'pro',
#  'max',
#  'leave',
#  'snapchat',
#  'right',
#  'camera',
#  'app',
#  'problem',
#  'xr',
#  'thought',
#  'depress',
#  'new',
#  'come',
#  'pink',
#  'suddenly',
#  'cure',
#  'confirm',
#  'pro',
#  'max',
#  'camera',
#  'insane',
#  'raw',
#  'filter',
#  'refuse',
#  'pay',
#  'designer',
#  'worker',
#  'ask',
#  'compensation',
#  'work',
#  'refuse',
#  'explained',
#  'money',
#  'day',
#  'ago',
#  'flex',
#  'brand',
#  'new',
#  'ipad',
#  'hmmm',
#  'seem',
#  'gross',
#  'let',
#  'start',
#  'fast',
#  'mode',
#  'pro',
#  'start',
#  'top',
#  'second',
#  'pas',
#  'perform',
#  'bad',
#  'pro',
#  'think',
#  'test',
#  'probably',
#  'level',
#  'similar',
#  'level',
#  'pro',
#  'pro',
#  'x',
#  'charge',
#  'phone',
#  'hour',
#  'step',
#  'upppp',
#  'pro',
#  'perfect',
#  'fit',
#  'magsafe',
#  'duo',
#  'charge',
#  'unaffected',
#  'much',
#  'good',
#  'start',
#  'astrophotography',
#  'unedited',
#  'edited',
#  'antenna',
#  'design',
#  ...]

# %%
negative_dict_counts = Counter(negative_words_list)

# %%
negative_output_dict_counts = dict((k, negative_dict_counts[k]) for k in selected_words)

negative_output_dict_counts
# Out:
# {'battery': 451,
#  'display': 148,
#  'camera': 607,
#  'pro': 3924,
#  'max': 1988,
#  'price': 190,
#  'upgrade': 343,
#  'color': 95,
#  'screen': 421}

# %%
plt.figure(figsize=(12,5))
plt.xticks(fontsize=13, rotation=90)
freq_dist = nltk.FreqDist(negative_output_dict_counts)
freq_dist.plot(cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
